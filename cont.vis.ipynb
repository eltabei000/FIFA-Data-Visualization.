# %% [markdown]
# ## Import LIBs

# %%
#!pip install seaborn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data

# %%
df = pd.read_csv(r"D:\Work\Route\C07\ONline\New folder\fifa.csv")

# %%
df.head()
# Out:
#        ID               Name  Age  \
# 0  158023           L. Messi   31
# 1   20801  Cristiano Ronaldo   33
# 2  190871          Neymar Jr   26
# 3  193080             De Gea   27
# 4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 88 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        18207 non-null  int64
#  1   Name                      18207 non-null  object
#  2   Age                       18207 non-null  int64
#  3   Photo                     18207 non-null  object
#  4   Nationality               18207 non-null  object
#  5   Flag                      18207 non-null  object
#  6   Overall                   18207 non-null  int64
#  7   Potential                 18207 non-null  int64
#  8   Club                      17966 non-null  object
#  9   Club Logo                 18207 non-null  object
#  10  Value                     18207 non-null  object
#  11  Wage                      18207 non-null  object
#  12  Special                   18207 non-null  int64
# ...

# %%
df.Name.unique()
# Out:
# array(['L. Messi', 'Cristiano Ronaldo', 'Neymar Jr', ..., 'B. Worman',
#        'D. Walker-Rice', 'G. Nugent'], dtype=object)

# %%
df.Name.value_counts()
# Out:
# Name
# J. Rodríguez    11
# Paulinho         8
# R. Williams      7
# J. Williams      7
# J. Gómez         6
#                 ..
# I. Anya          1
# P. Hoban         1
# Hugo Basto       1
# Kanu             1
# G. Nugent        1
# Name: count, Length: 17194, dtype: int64

# %% [markdown]
# ## Seaborn

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
sns.distplot(df['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
df.Age.min()
# Out:
# 16

# %%
df.Age.max()
# Out:
# 45

# %%
sns.histplot(df['Age'],kde = True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.kdeplot(df['Age'],fill = True,color = 'red')
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag', 'Overall',
#        'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
df.Nationality.value_counts()
# Out:
# Nationality
# England                 1662
# Germany                 1198
# Spain                   1072
# Argentina                937
# France                   914
#                         ...
# New Caledonia              1
# Fiji                       1
# São Tomé & Príncipe        1
# United Arab Emirates       1
# Botswana                   1
# Name: count, Length: 164, dtype: int64

# %%
df.Club.value_counts()
# Out:
# Club
# FC Barcelona                 33
# Valencia CF                  33
# Fortuna Düsseldorf           33
# Cardiff City                 33
# Rayo Vallecano               33
#                              ..
# América FC (Minas Gerais)    20
# Fluminense                   20
# Sligo Rovers                 19
# Limerick FC                  19
# Derry City                   18
# Name: count, Length: 651, dtype: int64

# %%
df['Preferred Foot'].value_counts()
# Out:
# Preferred Foot
# Right    13948
# Left      4211
# Name: count, dtype: int64

# %%
sns.countplot(x= 'Preferred Foot', data= df)
plt.title('count of Preferred Foot')
plt.show()

# %%
df.Position.value_counts()
# Out:
# Position
# ST     2152
# GK     2025
# CB     1778
# CM     1394
# LB     1322
# RB     1291
# RM     1124
# LM     1095
# CAM     958
# CDM     948
# RCB     662
# LCB     648
# LCM     395
# RCM     391
# LW      381
# RW      370
# RDM     248
# LDM     243
# LS      207
# RS      203
# RWB      87
# LWB      78
# CF       74
# LAM      21
# RAM      21
# RF       16
# LF       15
# Name: count, dtype: int64

# %%
sns.countplot(x= 'Position', data= df)
plt.xticks(rotation = 70)
plt.title('count of Position')
plt.show()

# %%
df['Real Face'].value_counts()
# Out:
# Real Face
# No     16505
# Yes     1654
# Name: count, dtype: int64

# %%
sns.countplot(x= 'Real Face', data= df,color = 'red')
# Out:
# <Axes: xlabel='Real Face', ylabel='count'>

# %%
sns.countplot(x= 'Real Face', data= df,hue = 'Preferred Foot' ,color = 'b')
# Out:
# <Axes: xlabel='Real Face', ylabel='count'>

# %%
sns.countplot(y= 'Real Face', data= df,hue = 'Preferred Foot' ,color = 'b')
# Out:
# <Axes: xlabel='count', ylabel='Real Face'>

# %%
df.Potential.min()
# Out:
# 48

# %%
df.Potential.max()
# Out:
# 95

# %%
sns.histplot(x = 'Potential', data = df)
# Out:
# <Axes: xlabel='Potential', ylabel='Count'>

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag', 'Overall',
#        'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
'Potential'
'International Reputation'

# %%
df['International Reputation'].max()
# Out:
# 5.0

# %%
df['International Reputation'].min()
# Out:
# 1.0

# %%
sns.stripplot(x ='International Reputation' ,y= 'Potential' ,data= df)
# Out:
# <Axes: xlabel='International Reputation', ylabel='Potential'>

# %%
sns.stripplot(x ='International Reputation' ,y= 'Potential' ,hue = 'Preferred Foot',data= df)
# Out:
# <Axes: xlabel='International Reputation', ylabel='Potential'>

# %%
sns.stripplot(x ='International Reputation',
              y= 'Potential',
              hue = 'Preferred Foot',
              dodge = 'True',
              jitter = 0.2,
              data= df)
# Out:
# <Axes: xlabel='International Reputation', ylabel='Potential'>

# %%
sns.stripplot(x ='International Reputation',
              y= 'Potential',
              hue = 'Preferred Foot',
              dodge = 'True',
              jitter = 0.4,
              alpha = 0.7,
              data= df)
# Out:
# <Axes: xlabel='International Reputation', ylabel='Potential'>

# %%
df.describe()
# Out:
#                   ID           Age       Overall     Potential       Special  \
# count   18207.000000  18207.000000  18207.000000  18207.000000  18207.000000
# mean   214298.338606     25.122206     66.238699     71.307299   1597.809908
# std     29965.244204      4.669943      6.908930      6.136496    272.586016
# min        16.000000     16.000000     46.000000     48.000000    731.000000
# 25%    200315.500000     21.000000     62.000000     67.000000   1457.000000
# 50%    221759.000000     25.000000     66.000000     71.000000   1635.000000
# 75%    236529.500000     28.000000     71.000000     75.000000   1787.000000
# max    246620.000000     45.000000     94.000000     95.000000   2346.000000
#
#        International Reputation     Weak Foot   Skill Moves  Jersey Number  \
# count              18159.000000  18159.000000  18159.000000   18147.000000
# mean                   1.113222      2.947299      2.361308      19.546096
# ...

# %%
sns.stripplot(x ='International Reputation' ,y= 'Potential' ,data= df)
# Out:
# <Axes: xlabel='International Reputation', ylabel='Potential'>

# %%
#boxplot
sns.boxplot(x ='International Reputation' ,y= 'Potential' ,data= df )
# Out:
# <Axes: xlabel='International Reputation', ylabel='Potential'>

# %%
sns.violinplot(x ='International Reputation' ,y= 'Potential', hue = 'Preferred Foot',data= df )
# Out:
# <Axes: xlabel='International Reputation', ylabel='Potential'>

# %% [markdown]
# ## tips data

# %%
df = sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
sns.countplot(x = 'sex', data =df)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(x = 'smoker', data =df)
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
sns.countplot(x = 'day', data =df)
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.countplot(x = 'time', data =df)
# Out:
# <Axes: xlabel='time', ylabel='count'>

# %%
sns.countplot(x = 'sex',hue = 'smoker' ,data =df)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.lmplot(x= 'total_bill', y = 'tip', data = df)

# %%
sns.pairplot(data = df)

# %%
sns.pairplot(data = df, hue = 'day')

# %%
sns.pairplot(data = df, hue = 'time')

# %% [markdown]
# ## Task

# %% [markdown]
# *** dataframe --> 'flights' from seaborn
# 1- explore the data
# 2- bar plot 'month'
# 3- query ==>  month == May
# plot a lineplot graph for years and passengers

# %%
df = sns.load_dataset('flights')

# %%
df.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
may_flight = df.query("month == 'May'")

# %%
may_flight
# Out:
#      year month  passengers
# 4    1949   May         121
# 16   1950   May         125
# 28   1951   May         172
# 40   1952   May         183
# 52   1953   May         229
# 64   1954   May         234
# 76   1955   May         270
# 88   1956   May         318
# 100  1957   May         355
# 112  1958   May         363
# 124  1959   May         420
# 136  1960   May         472

# %%
sns.lineplot(x= 'year', y='passengers' , data = may_flight)
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
year_flight = df.query("year == 1960")

# %%
year_flight
# Out:
#      year month  passengers
# 132  1960   Jan         417
# 133  1960   Feb         391
# 134  1960   Mar         419
# 135  1960   Apr         461
# 136  1960   May         472
# 137  1960   Jun         535
# 138  1960   Jul         622
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432

# %%
sns.lineplot(x= 'month', y='passengers' , data = year_flight)
# Out:
# <Axes: xlabel='month', ylabel='passengers'>

# %% [markdown]
# ## Plotly

# %%
import plotly.express as px

# %%
x = np.array([1,2,3])
y = np.array([6,7,8])

# %%
px.bar(y,x)

# %%
df = sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.day.value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
px.pie(df,values= 'tip', names = 'day' )

# %% [markdown]
# ## 3D

# %%
x= [1,2,3,4,5]
y = [1,4,9,18,25]
z = [1,8,27,60,100]

# %%
fig = plt.figure()
ax = plt.axes(projection = '3d')

# %%
fig = plt.figure()
ax = plt.axes(projection = '3d')
ax.plot3D(x,y,z)

# %% [markdown]
# ## image

# %%
import matplotlib.image as img

# %%
plt.figure(figsize = (6,5))

# read image
image = img.imread(r"C:\Users\LENOVO\Downloads\_72c05e26-089e-4e15-9dc8-cdb9b9b03d54.jpeg")

# %%
image
# Out:
# array([[[240, 246, 246],
#         [240, 246, 246],
#         [241, 247, 247],
#         ...,
#         [240, 246, 246],
#         [240, 246, 246],
#         [240, 246, 246]],
#
#        [[240, 246, 246],
#         [241, 247, 247],
#         [241, 247, 247],
#         ...,
#         [241, 247, 247],
#         [241, 247, 247],
#         [241, 247, 247]],
#
#        [[241, 247, 247],
#         [241, 247, 247],
#         [242, 248, 248],
#         ...,
#         [241, 247, 247],
#         [242, 248, 248],
#         [242, 248, 248]],
#
#        ...,
#
#        [[ 94,  96,  95],
#         [ 96,  98,  97],
#         [ 93,  95,  94],
#         ...,
#         [242, 248, 248],
#         [241, 247, 247],
#         [241, 247, 247]],
#
#        [[ 94,  96,  95],
#         [ 96,  98,  97],
#         [ 93,  95,  94],
#         ...,
#         [242, 248, 248],
#         [241, 247, 247],
#         [241, 247, 247]],
#
#        [[ 94,  96,  95],
#         [ 96,  98,  97],
#         [ 93,  95,  94],
# ...

# %%
#show image
plt.imshow(image)

# %%
#show image
plt.imshow(image)
plt.axis('off')
plt.show()
